# %% [markdown]
# ### Record linkage with Splink
#
# This notebook provides a short worked example using the Splink [quick and dirty persons model](https://moj-analytical-services.github.io/splink/demos/examples/duckdb/quick_and_dirty_persons.html).

# %%
from splink.duckdb.linker import DuckDBLinker
from splink.duckdb.blocking_rule_library import block_on
import splink.duckdb.comparison_library as cl
import pandas as pd

# %% [markdown]
# I'm using a slightly modified dataset of [Miami-Dade County Jail Bookings](https://gis-mdc.opendata.arcgis.com/datasets/c2275711ced240c6bc4e998ee1910e85).
#
# The dataset used in this notebook can also be found within this GitHub repository. There are 266,656 unique forename, surname and dob combinations within the dataset.

# %%
df = pd.read_csv('data_md_jb_v2.csv', low_memory=False)
df.head()
# Out:
#    unique_id               book_date     date_eu          defendant  \
# 0     322567  2021/12/01 05:00:00+00  01/12/2021      GERT ALLYSSON
# 1     402605  2023/09/29 04:00:00+00  29/09/2023       THOMAS COLMY
# 2     300730  2021/05/29 04:00:00+00  29/05/2021  FARMER CORNELL  L
# 3      78183  2016/09/24 04:00:00+00  24/09/2016     SCHAPPERT COLE
# 4     377120  2023/03/09 05:00:00+00  09/03/2023   BENNETT TERRY  T
#
#           surname first_name                   address       city_state_zip  \
# 0            GERT   ALLYSSON  JAKOBFUGLISTRASSE 18 804            ZURICH YY
# 1          THOMAS      COLMY             1368 JAMES CT  ZIONVILLE IN  46077
# 2  FARMER CORNELL          L           2209 ESHCOL AVE       ZION FL  60099
# 3       SCHAPPERT       COLE       1106 CARDINAL DRIVE              ZION IL
# 4   BENNETT TERRY          T         1109 PHEASANT RUN       ZION IL  60099
#
#           dob               charge1              charge2  \
# 0  1995-06-02        CONT SUBS/POSS       CONT SUBS/POSS
# 1  1981-07-05   OUT-OF-CNTY/WARRANT                  NaN
# 2  1988-08-20               BATTERY                  NaN
# 3  1991-05-28   UTTER FORGED INSTRU  RESIST OFF W/O VIOL
# 4  1992-06-05  SMO/CAN/M/HE/PP/PROH                  NaN
#
#                 charge3    zip       city state
# 0  DRUG PARAPHERNA/POSN    NaN     ZURICH    YY
# 1                   NaN  46077  ZIONVILLE    IN
# 2                   NaN  60099       ZION    FL
# 3  DEBIT CARD/UNLAW/USE    NaN       ZION    IL
# 4                   NaN  60099       ZION    IL

# %%
unique_persons_raw = df.drop_duplicates(subset=['defendant', 'dob']).shape[0]
print("Unique number of individuals in raw dataset by combining name and dob':", unique_persons_raw)
# Out:
# Unique number of individuals in raw dataset by combining name and dob': 266656

# %% [markdown]
# ### 1.Settings
#
# I've modified the suggested settings in the Splink walkthrough to reflect the columns available in the sample dataset.
#
# A full guide on the blocking rules can be found at this link: https://moj-analytical-services.github.io/splink/topic_guides/blocking/blocking_rules.html

# %%
settings = {
    "link_type": "dedupe_only",
    "blocking_rules_to_generate_predictions": [
        block_on("defendant"),
        block_on(["substr(defendant,1,6)", "dob"]),
    ],
    "comparisons": [
        cl.jaro_at_thresholds("defendant", [0.9, 0.7], term_frequency_adjustments=True),
        cl.levenshtein_at_thresholds("dob", [1, 2]),
    ],       

}

# %% [markdown]
# ### 2. Parameters
#
# See here: https://moj-analytical-services.github.io/splink/demos/tutorials/04_Estimating_model_parameters.html

# %%
# these are unchanged from SplinkQD documentation tutorial
linker = DuckDBLinker(df, settings, set_up_basic_logging=False)
deterministic_rules = [
    "l.defendant = r.defendant",
    "l.defendant = r.defendant and l.dob = r.dob",
]

linker.estimate_probability_two_random_records_match(deterministic_rules, recall=0.6)

linker.estimate_u_using_random_sampling(max_pairs=2e6)

# %% [markdown]
# ### 3. Results

# %%
results = linker.predict(threshold_match_probability=0.75)
# Out:
#  -- WARNING --
# You have called predict(), but there are some parameter estimates which have neither been estimated or specified in your settings dictionary.  To produce predictions the following untrained trained parameters will use default values.
# Comparison: 'defendant':
#     m values not fully trained
# Comparison: 'dob':
#     m values not fully trained

# %%
results.as_pandas_dataframe(limit=5)
# Out:
#     match_weight  match_probability  unique_id_l  unique_id_r  \
# 0        1.68325           0.762555         4922        11063
# 1        1.68325           0.762555         3854        11063
# 2        1.68325           0.762555       264718       267793
# 3        1.68325           0.762555       258668       267793
# 4        1.68325           0.762555       165746       267793
# 5        1.68325           0.762555          563       133317
# 6        1.68325           0.762555       101659       146990
# 7        1.68325           0.762555       101659       162534
# 8        1.68325           0.762555       101659       204779
# 9        1.68325           0.762555       101659       207043
# 10       1.68325           0.762555       101659       214579
#
#                defendant_l             defendant_r  gamma_defendant  \
# 0          MORILLO RICHARD         MORILLO RICHARD                3
# 1          MORILLO RICHARD         MORILLO RICHARD                3
# 2   LEEMAN COURTNEY  BROCK  LEEMAN COURTNEY  BROCK                3
# 3   LEEMAN COURTNEY  BROCK  LEEMAN COURTNEY  BROCK                3
# 4   LEEMAN COURTNEY  BROCK  LEEMAN COURTNEY  BROCK                3
# 5           CASTRO MELISSA          CASTRO MELISSA                3
# 6   BANEGAS JOSUE  GABRIEL  BANEGAS JOSUE  GABRIEL                3
# 7   BANEGAS JOSUE  GABRIEL  BANEGAS JOSUE  GABRIEL                3
# 8   BANEGAS JOSUE  GABRIEL  BANEGAS JOSUE  GABRIEL                3
# 9   BANEGAS JOSUE  GABRIEL  BANEGAS JOSUE  GABRIEL                3
# 10  BANEGAS JOSUE  GABRIEL  BANEGAS JOSUE  GABRIEL                3
#
#          dob_l       dob_r  gamma_dob match_key
# 0   1977-09-19  1977-09-17          2         0
# 1   1977-09-19  1977-09-17          2         0
# 2   1979-02-23  1979-06-23          2         0
# 3   1979-02-23  1979-06-23          2         0
# 4   1979-02-23  1979-06-23          2         0
# 5   1988-06-08  1980-06-08          2         0
# 6   1986-01-14  1981-01-14          2         0
# 7   1986-01-14  1981-01-14          2         0
# 8   1986-01-14  1981-01-14          2         0
# 9   1986-01-14  1981-01-14          2         0
# 10  1986-01-14  1981-01-14          2         0

# %% [markdown]
# ### 4. Adding unique id to persons and using results
#
# SpinkQD identified 27,490 duplicate individuals from our original dataset.

# %%
#add in cluster id
clusters = linker.cluster_pairwise_predictions_at_threshold(results, threshold_match_probability=0.5)
clusters.as_pandas_dataframe(limit=5)
# Out:
#    cluster_id  unique_id               book_date     date_eu  \
# 0       19986     297447  2021/04/29 04:00:00+00  29/04/2021
# 1      105241     297720  2021/05/04 04:00:00+00  04/05/2021
# 2       21799     298104  2021/05/08 04:00:00+00  08/05/2021
# 3      298242     298242  2021/05/07 04:00:00+00  07/05/2021
# 4      130110     298745  2021/05/11 04:00:00+00  11/05/2021
# 5      229709     298749  2021/05/11 04:00:00+00  11/05/2021
# 6       47570     298750  2021/05/10 04:00:00+00  10/05/2021
# 7      274729     298767  2021/05/11 04:00:00+00  11/05/2021
# 8       46127     298806  2021/05/13 04:00:00+00  13/05/2021
# 9       75682     298814  2021/05/15 04:00:00+00  15/05/2021
#
#                         defendant                surname first_name  \
# 0                     SCOTT LARRY                  SCOTT      LARRY
# 1            BROWN DERIK  LAMOYNE            BROWN DERIK    LAMOYNE
# 2        MASSEY PIERRE  ALEXANDER          MASSEY PIERRE  ALEXANDER
# 3                 STANFORD DELVON               STANFORD     DELVON
# 4          LEWIS CAMILLE  DANYELL          LEWIS CAMILLE    DANYELL
# 5               LINARES ALEXANDER                LINARES  ALEXANDER
# 6            SMITH GREGORY  KEITH          SMITH GREGORY      KEITH
# 7         MARSHALL LEXIE  NATINCE         MARSHALL LEXIE    NATINCE
# 8  GONZALEZDELAPENA LUIS  ALBERTO  GONZALEZDELAPENA LUIS    ALBERTO
# 9             FERNANDEZ FRANCISCO              FERNANDEZ  FRANCISCO
#
#                  address           city_state_zip         dob  \
# 0        ADDRESS UNKNOWN                 MIAMI FL  1959-03-20
# 1         15020 TYLER ST          MIAMI FL  33176  1986-11-27
# 2        ADDRESS UNKNOWN                 MIAMI FL  1973-03-18
# 3  3094 E LIVINGSTON AVE       COLUMBUS OH  43227  1998-09-23
# 4     1525 NW 60TH ST  6          MIAMI FL  33142  1986-12-21
# 5         2509 W 72ND ST        HIALEAH FL  33016  1971-03-30
# 6     4800 NW 170 ST.ERR  MIAMI GAREENS FL  33055  1966-06-23
# 7         1811 SW 48 AVE      WEST PARK FL  33023  1997-04-25
# 8         385 WEST 46 ST               HIALEAH FL  1997-07-01
# 9          155 E 11TH ST        HIALEAH FL  33010  1985-12-10
#
#                 charge1               charge2              charge3    zip  \
# 0  ALC/BEV CONSUME/SERV                  None                 None   None
# 1    BATTERY/AGGRAVATED   CHILD ABUSE/NO HARM  CHILD ABUSE/NO HARM  33176
# 2   PETIT THEFT 2> CONV                  None                 None   None
# 3     CANNABIS/PURCHASE                  None                 None  43227
# 4               BATTERY                  None                 None  33142
# 5         DWLS/HABITUAL                  None                 None  33016
# 6          ALIAS CAPIAS                  None                 None  33055
# 7        DWLS/KNOWINGLY                  None                 None  33023
# 8    CANNABIS/POSN/0-20  DRUG PARAPHERNA/POSN     VEH REG/NOT HAVE   None
# 9  RET TFT/300>/BF 10/1  RET TFT/300>/BF 10/1                 None  33010
#
#             city state  __splink_salt  tf_defendant
# 0          MIAMI    FL       0.068558      0.000024
# 1          MIAMI    FL       0.849602      0.000024
# 2          MIAMI    FL       0.801492      0.000041
# 3       COLUMBUS    OH       0.542894      0.000002
# 4          MIAMI    FL       0.500077      0.000002
# 5        HIALEAH    FL       0.456094      0.000019
# 6  MIAMI GAREENS    FL       0.580879      0.000005
# 7      WEST PARK    FL       0.829338      0.000005
# 8        HIALEAH    FL       0.781381      0.000002
# 9        HIALEAH    FL       0.031745      0.000036

# %%
clusters.to_csv('cluster_results.csv', overwrite=True, low_memory=False)
results_df = pd.read_csv('cluster_results.csv')

unique_persons_splinkQD = results_df.drop_duplicates('cluster_id').shape[0]
print("Unique number of individuals after Splink Quick and Dirty':", unique_persons_splinkQD)
# Out:
# C:\Users\agari\AppData\Local\Temp\ipykernel_5844\1666739761.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   results_df = pd.read_csv('cluster_results.csv')
# Unique number of individuals after Splink Quick and Dirty': 239166

# %%
difference = unique_persons_raw - unique_persons_splinkQD
print("Number of duplicate persons found in raw data':", difference)
# Out:
# Number of duplicate persons found in raw data': 27490
