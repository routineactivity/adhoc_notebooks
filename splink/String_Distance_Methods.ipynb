# %%
import pandas as pd
import Levenshtein # levenshtein distance
from sklearn.feature_extraction.text import TfidfVectorizer # cosine similarity
from sklearn.metrics.pairwise import cosine_similarity # cosine similarity
import jellyfish # soundex

# %%
# import names data - premier league players
data = pd.read_csv('names_data.csv')
data.head()
# Out:
#    forename_a                surname_a    id_a  forename_b  \
# 0       Aaron         Anthony Connolly  456123       Aaron
# 1       Aaron                Cresswell  456124        Aran
# 2       Aaron                 Ramsdale  456125       Aaron
# 3       Aaron              Wan-Bissaka  456126       Aaron
# 4  Abd-Al-Ali  Morakinyo Olaposi Koiki  456127  Abd-Al-Ali
#
#                  surname_b    id_b
# 0         Anthony Connolly  456123
# 1                Cresswell  456124
# 2                 Ramsdale  456125
# 3              Wan-Bissaka  456126
# 4  Morakinyo Olaposi Koiki  456127

# %%
# combine name and psuedo ID number into strings
data['combined_a'] = data['forename_a'] + ' ' + data['surname_a'] + ' ' + data['id_a'].astype(str)
data['combined_b'] = data['forename_b'] + ' ' + data['surname_b'] + ' ' + data['id_b'].astype(str)
data.head()
# Out:
#    forename_a                surname_a    id_a  forename_b  \
# 0       Aaron         Anthony Connolly  456123       Aaron
# 1       Aaron                Cresswell  456124        Aran
# 2       Aaron                 Ramsdale  456125       Aaron
# 3       Aaron              Wan-Bissaka  456126       Aaron
# 4  Abd-Al-Ali  Morakinyo Olaposi Koiki  456127  Abd-Al-Ali
#
#                  surname_b    id_b                                 combined_a  \
# 0         Anthony Connolly  456123              Aaron Anthony Connolly 456123
# 1                Cresswell  456124                     Aaron Cresswell 456124
# 2                 Ramsdale  456125                      Aaron Ramsdale 456125
# 3              Wan-Bissaka  456126                   Aaron Wan-Bissaka 456126
# 4  Morakinyo Olaposi Koiki  456127  Abd-Al-Ali Morakinyo Olaposi Koiki 456127
#
#                                   combined_b
# 0              Aaron Anthony Connolly 456123
# 1                      Aran Cresswell 456124
# 2                      Aaron Ramsdale 456125
# 3                   Aaron Wan-Bissaka 456126
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127

# %% [markdown]
# ## Method 1: Jaccard

# %%
def jaccard_similarity(str1, str2):
    set1 = set(str1.split())
    set2 = set(str2.split())
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union

# calc jaccard similarity of combined strings
data['jaccard_similarity'] = data.apply(lambda row: jaccard_similarity(row['combined_a'], row['combined_b']), axis=1)
data[['combined_a', 'combined_b', 'jaccard_similarity']].head()
# Out:
#                                   combined_a  \
# 0              Aaron Anthony Connolly 456123
# 1                     Aaron Cresswell 456124
# 2                      Aaron Ramsdale 456125
# 3                   Aaron Wan-Bissaka 456126
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127
#
#                                   combined_b  jaccard_similarity
# 0              Aaron Anthony Connolly 456123                 1.0
# 1                      Aran Cresswell 456124                 0.5
# 2                      Aaron Ramsdale 456125                 1.0
# 3                   Aaron Wan-Bissaka 456126                 1.0
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127                 1.0

# %% [markdown]
# ## Method 2: Cosine Similarity

# %%
# create tf-idf vectors for combined name strings
# term frequency-inverse document frequency
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(data['combined_a'].tolist() + data['combined_b'].tolist())

# calc the cosine similarity
cosine_similarities = cosine_similarity(tfidf_matrix[:len(data)], tfidf_matrix[len(data):])
data['cosine_similarity'] = [cosine_similarities[i][i] for i in range(len(cosine_similarities))]

data[['combined_a', 'combined_b', 'cosine_similarity']].head()
# Out:
#                                   combined_a  \
# 0              Aaron Anthony Connolly 456123
# 1                     Aaron Cresswell 456124
# 2                      Aaron Ramsdale 456125
# 3                   Aaron Wan-Bissaka 456126
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127
#
#                                   combined_b  cosine_similarity
# 0              Aaron Anthony Connolly 456123           1.000000
# 1                      Aran Cresswell 456124           0.684849
# 2                      Aaron Ramsdale 456125           1.000000
# 3                   Aaron Wan-Bissaka 456126           1.000000
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127           1.000000

# %% [markdown]
# ## Method 3: Leveshtein Distance

# %%
# calc levenshtein distance between the combined strings
data['levenshtein_distance'] = data.apply(lambda row: Levenshtein.distance(row['combined_a'], row['combined_b']), axis=1)

data[['combined_a', 'combined_b', 'levenshtein_distance']].head()
# Out:
#                                   combined_a  \
# 0              Aaron Anthony Connolly 456123
# 1                     Aaron Cresswell 456124
# 2                      Aaron Ramsdale 456125
# 3                   Aaron Wan-Bissaka 456126
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127
#
#                                   combined_b  levenshtein_distance
# 0              Aaron Anthony Connolly 456123                     0
# 1                      Aran Cresswell 456124                     2
# 2                      Aaron Ramsdale 456125                     0
# 3                   Aaron Wan-Bissaka 456126                     0
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127                     0

# %% [markdown]
# ## Method 4: Soundex

# %%
# calc soundex code for combined strings
data['soundex_a'] = data['combined_a'].apply(jellyfish.soundex)
data['soundex_b'] = data['combined_b'].apply(jellyfish.soundex)

# Determine if the Soundex codes are the same
data['soundex_match'] = data['soundex_a'] == data['soundex_b']

data[['combined_a', 'combined_b', 'soundex_a', 'soundex_b', 'soundex_match']].head()
# Out:
#                                   combined_a  \
# 0              Aaron Anthony Connolly 456123
# 1                     Aaron Cresswell 456124
# 2                      Aaron Ramsdale 456125
# 3                   Aaron Wan-Bissaka 456126
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127
#
#                                   combined_b soundex_a soundex_b  \
# 0              Aaron Anthony Connolly 456123      A655      A655
# 1                      Aran Cresswell 456124      A652      A652
# 2                      Aaron Ramsdale 456125      A656      A656
# 3                   Aaron Wan-Bissaka 456126      A655      A655
# 4  Abd-Al-Ali Morakinyo Olaposi Koiki 456127      A134      A134
#
#    soundex_match
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %% [markdown]
# ### View different similarity measures

# %%
data.head(50)
# Out:
#     forename_a                       surname_a    id_a  forename_b  \
# 0        Aaron                Anthony Connolly  456123       Aaron
# 1        Aaron                       Cresswell  456124        Aran
# 2        Aaron                        Ramsdale  456125       Aaron
# 3        Aaron                     Wan-Bissaka  456126       Aaron
# 4   Abd-Al-Ali         Morakinyo Olaposi Koiki  456127  Abd-Al-Ali
# 5         Adam                            Idah  456128        Adam
# 6         Adam                         Lallana  456129        Adam
# 7         Adam                          Masina  456130        Adam
# 8         Adam                           Smith  456131        Adam
# 9         Adam                         Webster  456132        Adam
# 10      Adrian                        Mariappa  456133      Adrian
# 11       Ahmed  Eissa El Mohamady Abdel Fattah  456134       Ahmed
# 12     Ainsley                  Maitland-Niles  456135     Ainsley
# 13        Akin                          Famewo  456136        Akin
# 14      Albian                           Ajeti  456137      Albian
# 15        Alex                        Cochrane  456138        Alex
# 16        Alex                           Iwobi  456139        Alex
# 17        Alex                        McCarthy  456140        Alex
# 18        Alex              Oxlade-Chamberlain  456141   Alexander
# 19   Alexander                          Tettey  456142   Alexander
# 20   Alexandre                       Jankewitz  456143   Alexandre
# 21   Alexandre                       Lacazette  456144   Alexandre
# 22   Alexandre          Nascimento Costa Silva  456145   Alexandre
# 23      Alexis                    Mac Allister  456146      Alexis
# 24       Alfie                           Lewis  456147       Alfie
# 25       Alfie                        Whiteman  456148       Alfie
# 26     Alireza                     Jahanbakhsh  456149     Alireza
# 27     Alisson                   Ramses Becker  456150     Alisson
# 28       Allan                   Saint-Maximin  456151       Allan
# 29       Andre                            Gray  456152       Andre
# 30     Andreas                     Christensen  456153     Andreas
# 31     Andreas         Hugo Hoelgebaum Pereira  456154     Andreas
# 32      Andrew                       Robertson  456155      Andrew
# 33      Andrew                          Surman  456156      Andrew
# 34      Andrii                      Yarmolenko  456157      Andrii
# 35      Andros                        Townsend  456158      Andros
# 36        Andy                         Carroll  456159        Andy
# 37        Andy                        Lonergan  456160        Andy
# 38      Angelo                         Ogbonna  456161      Angelo
# 39       Angus                            Gunn  456162       Angus
# 40     Anthony                Driscoll-Glennon  456163     Anthony
# 41     Anthony                          Gordon  456164     Anthony
# 42     Anthony                         Martial  456165     Anthony
# 43       Anwar                        El Ghazi  456166       Anwar
# 44      Archie                            Mair  456167      Archie
# 45     Armando                           Broja  456168     Armando
# 46      Arnaut              Danjuma Groeneveld  456169      Arnaut
# 47      Arthur                         Masuaku  456170      Arthur
# 48       Artur                           Boruc  456171       Artur
# 49      Ashley                          Barnes  456172      Ashley
#
#                          surname_b    id_b  \
# 0                 Anthony Connolly  456123
# 1                        Cresswell  456124
# 2                         Ramsdale  456125
# 3                      Wan-Bissaka  456126
# 4          Morakinyo Olaposi Koiki  456127
# 5                             Idah  456128
# 6                          Lallana  456129
# 7                           Masina  456130
# 8                            Smith  456131
# 9                          Webster  456132
# 10                        Mariappa  456133
# 11  Eissa El Mohamady Abdel Fattah  456134
# 12                  Maitland-Niles  456135
# 13                          Famewo  456138
# 14                           Ajeti  456137
# 15                        Cochrane  456138
# 16                           Iwobi  456139
# 17                        McCarthy  456140
# 18              Oxlade-Chamberlain  456141
# 19                          Tettey  456142
# 20                       Jankewitz  456143
# 21                       Lacazette  456144
# 22          Nascimento Costa Silva  456145
# 23                    Mac Allister  456146
# 24                           Lewis  456147
# 25                        Whiteman  456148
# 26                     Jahanbakhsh  456149
# 27                   Ramses Becker  456150
# 28                   Saint-Maximin  456151
# 29                            Gray  456152
# 30                     Christensen  456153
# 31         Hugo Hoelgebaum Pereira  456154
# 32                       Robertson  456155
# 33                          Surman  456156
# 34                      Yarmolenko  456157
# 35                        Townsend  456158
# 36                         Carroll  456159
# 37                        Lonergan  456160
# 38                         Ogbonna  456161
# 39                            Gunn  456165
# 40                Driscoll-Glennon  456163
# 41                          Gordon  456164
# 42                         Martial  456165
# 43                        El Ghazi  456166
# 44                            Mair  456167
# 45                           Broja  456168
# 46              Danjuma Groeneveld  456169
# 47                         Masuaku  456170
# 48                           Boruc  456171
# 49                          Barnes  456172
#
#                                      combined_a  \
# 0                 Aaron Anthony Connolly 456123
# 1                        Aaron Cresswell 456124
# 2                         Aaron Ramsdale 456125
# 3                      Aaron Wan-Bissaka 456126
# 4     Abd-Al-Ali Morakinyo Olaposi Koiki 456127
# 5                              Adam Idah 456128
# 6                           Adam Lallana 456129
# 7                            Adam Masina 456130
# 8                             Adam Smith 456131
# 9                           Adam Webster 456132
# 10                       Adrian Mariappa 456133
# 11  Ahmed Eissa El Mohamady Abdel Fattah 456134
# 12                Ainsley Maitland-Niles 456135
# 13                           Akin Famewo 456136
# 14                          Albian Ajeti 456137
# 15                         Alex Cochrane 456138
# 16                            Alex Iwobi 456139
# 17                         Alex McCarthy 456140
# 18               Alex Oxlade-Chamberlain 456141
# 19                      Alexander Tettey 456142
# 20                   Alexandre Jankewitz 456143
# 21                   Alexandre Lacazette 456144
# 22      Alexandre Nascimento Costa Silva 456145
# 23                   Alexis Mac Allister 456146
# 24                           Alfie Lewis 456147
# 25                        Alfie Whiteman 456148
# 26                   Alireza Jahanbakhsh 456149
# 27                 Alisson Ramses Becker 456150
# 28                   Allan Saint-Maximin 456151
# 29                            Andre Gray 456152
# 30                   Andreas Christensen 456153
# 31       Andreas Hugo Hoelgebaum Pereira 456154
# 32                      Andrew Robertson 456155
# 33                         Andrew Surman 456156
# 34                     Andrii Yarmolenko 456157
# 35                       Andros Townsend 456158
# 36                          Andy Carroll 456159
# 37                         Andy Lonergan 456160
# 38                        Angelo Ogbonna 456161
# 39                            Angus Gunn 456162
# 40              Anthony Driscoll-Glennon 456163
# 41                        Anthony Gordon 456164
# 42                       Anthony Martial 456165
# 43                        Anwar El Ghazi 456166
# 44                           Archie Mair 456167
# 45                         Armando Broja 456168
# 46             Arnaut Danjuma Groeneveld 456169
# 47                        Arthur Masuaku 456170
# 48                           Artur Boruc 456171
# 49                         Ashley Barnes 456172
#
#                                      combined_b  jaccard_similarity  \
# 0                 Aaron Anthony Connolly 456123                 1.0
# 1                         Aran Cresswell 456124                 0.5
# 2                         Aaron Ramsdale 456125                 1.0
# 3                      Aaron Wan-Bissaka 456126                 1.0
# 4     Abd-Al-Ali Morakinyo Olaposi Koiki 456127                 1.0
# 5                              Adam Idah 456128                 1.0
# 6                           Adam Lallana 456129                 1.0
# 7                            Adam Masina 456130                 1.0
# 8                             Adam Smith 456131                 1.0
# 9                           Adam Webster 456132                 1.0
# 10                       Adrian Mariappa 456133                 1.0
# 11  Ahmed Eissa El Mohamady Abdel Fattah 456134                 1.0
# 12                Ainsley Maitland-Niles 456135                 1.0
# 13                           Akin Famewo 456138                 0.5
# 14                          Albian Ajeti 456137                 1.0
# 15                         Alex Cochrane 456138                 1.0
# 16                            Alex Iwobi 456139                 1.0
# 17                         Alex McCarthy 456140                 1.0
# 18          Alexander Oxlade-Chamberlain 456141                 0.5
# 19                      Alexander Tettey 456142                 1.0
# 20                   Alexandre Jankewitz 456143                 1.0
# 21                   Alexandre Lacazette 456144                 1.0
# 22      Alexandre Nascimento Costa Silva 456145                 1.0
# 23                   Alexis Mac Allister 456146                 1.0
# 24                           Alfie Lewis 456147                 1.0
# 25                        Alfie Whiteman 456148                 1.0
# 26                   Alireza Jahanbakhsh 456149                 1.0
# 27                 Alisson Ramses Becker 456150                 1.0
# 28                   Allan Saint-Maximin 456151                 1.0
# 29                            Andre Gray 456152                 1.0
# 30                   Andreas Christensen 456153                 1.0
# 31       Andreas Hugo Hoelgebaum Pereira 456154                 1.0
# 32                      Andrew Robertson 456155                 1.0
# 33                         Andrew Surman 456156                 1.0
# 34                     Andrii Yarmolenko 456157                 1.0
# 35                       Andros Townsend 456158                 1.0
# 36                          Andy Carroll 456159                 1.0
# 37                         Andy Lonergan 456160                 1.0
# 38                        Angelo Ogbonna 456161                 1.0
# 39                            Angus Gunn 456165                 0.5
# 40              Anthony Driscoll-Glennon 456163                 1.0
# 41                        Anthony Gordon 456164                 1.0
# 42                       Anthony Martial 456165                 1.0
# 43                        Anwar El Ghazi 456166                 1.0
# 44                           Archie Mair 456167                 1.0
# 45                         Armando Broja 456168                 1.0
# 46             Arnaut Danjuma Groeneveld 456169                 1.0
# 47                        Arthur Masuaku 456170                 1.0
# 48                           Artur Boruc 456171                 1.0
# 49                         Ashley Barnes 456172                 1.0
#
#     cosine_similarity  levenshtein_distance soundex_a soundex_b  soundex_match
# 0            1.000000                     0      A655      A655           True
# 1            0.684849                     2      A652      A652           True
# 2            1.000000                     0      A656      A656           True
# 3            1.000000                     0      A655      A655           True
# 4            1.000000                     0      A134      A134           True
# 5            1.000000                     0      A353      A353           True
# 6            1.000000                     0      A354      A354           True
# 7            1.000000                     0      A355      A355           True
# 8            1.000000                     0      A352      A352           True
# 9            1.000000                     0      A351      A351           True
# 10           1.000000                     0      A365      A365           True
# 11           1.000000                     0      A532      A532           True
# 12           1.000000                     0      A524      A524           True
# 13           0.662597                     1      A251      A251           True
# 14           1.000000                     0      A415      A415           True
# 15           1.000000                     0      A422      A422           True
# 16           1.000000                     0      A421      A421           True
# 17           1.000000                     0      A425      A425           True
# 18           0.796351                     5      A422      A425          False
# 19           1.000000                     0      A425      A425           True
# 20           1.000000                     0      A425      A425           True
# 21           1.000000                     0      A425      A425           True
# 22           1.000000                     0      A425      A425           True
# 23           1.000000                     0      A422      A422           True
# 24           1.000000                     0      A414      A414           True
# 25           1.000000                     0      A413      A413           True
# 26           1.000000                     0      A462      A462           True
# 27           1.000000                     0      A425      A425           True
# 28           1.000000                     0      A452      A452           True
# 29           1.000000                     0      A536      A536           True
# 30           1.000000                     0      A536      A536           True
# 31           1.000000                     0      A536      A536           True
# 32           1.000000                     0      A536      A536           True
# 33           1.000000                     0      A536      A536           True
# 34           1.000000                     0      A536      A536           True
# 35           1.000000                     0      A536      A536           True
# 36           1.000000                     0      A532      A532           True
# 37           1.000000                     0      A534      A534           True
# 38           1.000000                     0      A524      A524           True
# 39           0.662597                     1      A522      A522           True
# 40           1.000000                     0      A535      A535           True
# 41           1.000000                     0      A535      A535           True
# 42           1.000000                     0      A535      A535           True
# 43           1.000000                     0      A564      A564           True
# 44           1.000000                     0      A625      A625           True
# 45           1.000000                     0      A655      A655           True
# 46           1.000000                     0      A653      A653           True
# 47           1.000000                     0      A636      A636           True
# 48           1.000000                     0      A636      A636           True
# 49           1.000000                     0      A241      A241           True
